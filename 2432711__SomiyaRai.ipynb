# %% [markdown]
# **3 Tasks - To - Do:**
#
# Please Solve all the Problems as instructed:
#
# **3.1 Problem - 1: Getting Started with Data Exploration - Some Warm up Exercises:**

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
dataset = pd.read_csv('/content/drive/MyDrive/Assignment1/WHR-2024-5CS037.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **1. Data Exploration and Understanding:**
#
# • Dataset Overview:
# 1. Load the dataset and display the first 10 rows.
# 2. Identify the number of rows and columns in the dataset.
# 3. List all the columns and their data types.

# %%
#1. Load the dataset and display the first 10 rows.

dataset.head(10)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# ...

# %%
#2. Identify the number of rows and columns in the dataset.
rows, cols = dataset.shape
print(f"Number of Rows: {rows}")
print(f"Number of Columns: {cols}")
# Out:
# Number of Rows: 143
# Number of Columns: 9

# %%
#3. List all the columns and their data types.
print("Columns and their data types:")
print(dataset.dtypes)
# Out:
# Columns and their data types:
# Country name                     object
# score                           float64
# Log GDP per capita              float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# Dystopia + residual             float64
# dtype: object

# %% [markdown]
# • Basic Statistics:
# 1. Calculate the mean, median, and standard deviation for the Score column.
# 2. Identify the country with the highest and lowest happiness scores.

# %%
#1. Calculate the mean, median, and standard deviation for the Score column.

mean_score = dataset['score'].mean()
median_score = dataset['score'].median()
std_dev_score = dataset['score'].std()

print(f"Mean Score: {mean_score}")
print(f"Median Score: {median_score}")
print(f"Standard Deviation of Score: {std_dev_score}")
# Out:
# Mean Score: 5.52758041958042
# Median Score: 5.785
# Standard Deviation of Score: 1.1707165099442995

# %%
#2. Identify the country with the highest and lowest happiness scores.

highest_score = dataset.loc[dataset['score'].idxmax()]
print(f"Country with the Highest Score: {highest_score['Country name']} ({highest_score['score']})")


lowest_score = dataset.loc[dataset['score'].idxmin()]
print(f"Country with the Lowest Score: {lowest_score['Country name']} ({lowest_score['score']})")
# Out:
# Country with the Highest Score: Finland (7.741)
# Country with the Lowest Score: Afghanistan (1.721)

# %% [markdown]
# • Missing Values:
# 1. Check if there are any missing values in the dataset. If so, display the total count for each column.

# %%
#1. Check if there are any missing values in the dataset. If so, display the total count for each column.

missing_values = dataset.isnull().sum()
print("Missing values in each column:")
print(missing_values)
# Out:
# Missing values in each column:
# Country name                    0
# score                           0
# Log GDP per capita              3
# Social support                  3
# Healthy life expectancy         3
# Freedom to make life choices    3
# Generosity                      3
# Perceptions of corruption       3
# Dystopia + residual             3
# dtype: int64

# %% [markdown]
# • Filtering and Sorting:
# 1. Filter the dataset to show only the countries with a Score greater than 7.5.
# 2. For the filtered dataset - Sort the dataset by GDP per Capita in descending order and display the
# top 10 rows.

# %%
#1. Filter the dataset to show only the countries with a Score greater than 7.5.
filtered_dataset = dataset[dataset['score'] > 7.5]
print("Countries with a Score greater than 7.5:")
filtered_dataset
# Out:
# Countries with a Score greater than 7.5:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
#
#    Perceptions of corruption  Dystopia + residual
# 0                      0.546                2.082
# 1                      0.548                1.881
# 2                      0.182                2.050

# %%
#2. For the filtered dataset - Sort the dataset by GDP per Capita in descending order.
sorted_filtered_dataset = filtered_dataset.sort_values(by='Log GDP per capita', ascending=False)
print("Top 10 Countries with Score > 7.5 sorted by GDP per Capita:")
sorted_filtered_dataset.head(10)
# Out:
# Top 10 Countries with Score > 7.5 sorted by GDP per Capita:
#   Country name  score  Log GDP per capita  Social support  \
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 0      Finland  7.741               1.844           1.572
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# 0                    0.695                         0.859       0.142
#
#    Perceptions of corruption  Dystopia + residual
# 1                      0.548                1.881
# 2                      0.182                2.050
# 0                      0.546                2.082

# %%
#2. For the filtered dataset - Sort the dataset by GDP per Capita in descending order and display the top 10 rows.

sorted_dataset = dataset.sort_values(by = 'Log GDP per capita', ascending = False)
print("Top 10 Countries by GDP per Capita:")
sorted_dataset.head(10)
# Out:
# Top 10 Countries by GDP per Capita:
#                  Country name  score  Log GDP per capita  Social support  \
# 7                  Luxembourg  7.122               2.141           1.355
# 16                    Ireland  6.838               2.129           1.390
# 29                  Singapore  6.523               2.118           1.361
# 21       United Arab Emirates  6.733               1.983           1.164
# 8                 Switzerland  7.060               1.970           1.425
# 6                      Norway  7.302               1.952           1.517
# 22              United States  6.725               1.939           1.392
# 85  Hong Kong S.A.R. of China  5.316               1.909           1.184
# 1                     Denmark  7.583               1.908           1.520
# 5                 Netherlands  7.319               1.901           1.462
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# ...

# %% [markdown]
# • Adding New Columns:
# 1. Create a new column called Happiness Category that categorizes countries into three categories
# based on their Score:
#
# Low − (Score < 4)
#
#    Medium − (4 ≤ Score ≤ 6)
#
#   High − (Score > 6)

# %%
#1. Create a new column called Happiness Category that categorizes countries into three categories based on their Score:

def categorize_happiness(score):
    if score < 4:
        return 'Low'
    elif 4 <= score <= 6:
        return 'Medium'
    else:
        return 'High'

dataset['Happiness Category'] = dataset['score'].apply(categorize_happiness)

print("Updated Dataset with Happiness Category:")
dataset[['Country name', 'score', 'Happiness Category']]
# Out:
# Updated Dataset with Happiness Category:
#          Country name  score Happiness Category
# 0             Finland  7.741               High
# 1             Denmark  7.583               High
# 2             Iceland  7.525               High
# 3              Sweden  7.344               High
# 4              Israel  7.341               High
# ..                ...    ...                ...
# 138  Congo (Kinshasa)  3.295                Low
# 139      Sierra Leone  3.245                Low
# 140           Lesotho  3.186                Low
# 141           Lebanon  2.707                Low
# 142       Afghanistan  1.721                Low
#
# [143 rows x 3 columns]

# %% [markdown]
# **2. Data Visualizations:**
#
# **• Bar Plot:** Plot the top 10 happiest countries by Score using a bar chart.
#
# **• Line Plot:** Plot the top 10 unhappiest countries by Score using a Line chart.
#
# **• Plot a histogram** for the Score column to show its distribution and also interpret.
#
# **• Scatter Plot:** Plot a scatter plot between GDP per Capita and Score to visualize their relationship.

# %%
import matplotlib.pyplot as plt

# %%
# Bar Plot

top_10_happiest = dataset.sort_values(by='score', ascending=False).head(10)

plt.figure(figsize=(10, 6))
plt.bar(top_10_happiest['Country name'], top_10_happiest['score'], color='skyblue')
plt.title('Top 10 Happiest Countries by Score')
plt.xlabel('Country')
plt.ylabel('Happiness Score')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Line Plot

top_10_unhappiest = dataset.sort_values(by='score', ascending=True).head(10)

plt.figure(figsize=(10, 6))
plt.plot(top_10_unhappiest['Country name'], top_10_unhappiest['score'], marker='o', color='red', linestyle='--')
plt.title('Top 10 Unhappiest Countries by Score')
plt.xlabel('Country')
plt.ylabel('Happiness Score')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#Plot a histogram for the Score column to show its distribution and also interpret.
import seaborn as sns

plt.figure(figsize=(8, 5))
sns.histplot(dataset['score'], bins=10, color='#BBDEFB', edgecolor='black', kde=True)
plt.title('Distribution of Happiness Scores')
plt.xlabel('Happiness Score')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

print("The histogram shows how the Happiness Scores are distributed all across the countries. \nThis allows us to observe whether the scores are concentrated in any particular range or spread evenly.")
# Out:
# The histogram shows how the Happiness Scores are distributed all across the countries.
# This allows us to observe whether the scores are concentrated in any particular range or spread evenly.

# %%
#Scatter Plot

plt.figure(figsize=(8, 6))
plt.scatter(dataset['Log GDP per capita'], dataset['score'], color='green', alpha=0.7)
plt.title('Scatter Plot: GDP per Capita vs Happiness Score')
plt.xlabel('Log GDP per Capita')
plt.ylabel('Happiness Score')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **3.2 Problem - 2 - Some Advance Data Exploration Task:**
#
# **Task - 1 - Setup Task - Preparing the South-Asia Dataset:**
#
# **Steps:**
#
# 1. Define the countries in South Asia with a list for example:
# south asian countries = ["Afghanistan", "Bangladesh", "Bhutan", "India",
# "Maldives", "Nepal", "Pakistan", "Srilanka"]
#
# 2. Use the list from step - 1 to filtered the dataset {i.e. filtered out matching dataset from list.}
#
# 3. Save the filtered dataframe as separate CSV files for future use.

# %%
# Step 1: Define the list of South Asian countries
south_asian_countries = ["Afghanistan", "Bangladesh", "Bhutan", "India", "Maldives", "Nepal", "Pakistan", "Sri Lanka"]

# Step 2: Filtered out matching dataset from list.
south_asia_data = dataset[dataset['Country name'].isin(south_asian_countries)]

print("Filtered Dataset for South Asian Countries:")
south_asia_data
# Out:
# Filtered Dataset for South Asian Countries:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 127                    0.586                         0.583       0.144
# 128                    0.513                         0.775       0.140
# 142                    0.242                         0.000       0.091
# ...

# %%
# Step 3: Save the filtered dataset as a separate CSV file
south_asia_data.to_csv('South_Asia.csv', index=False)

print("Filtered dataset saved as 'South_Asia.csv'")
# Out:
# Filtered dataset saved as 'South_Asia.csv'

# %% [markdown]
# **Task - 2 - Composite Score Ranking:**
#
# **Tasks:**
#
# 1. Using the SouthAsia DataFrame, create a new column called Composite Score that combines the
# following metrics:
#
# Composite Score = 0.40 × GDP per Capita + 0.30 × Social Support
# + 0.30 × Healthy Life Expectancy
#
# 2. Rank the South Asian countries based on the Composite Score in descending order.
#
# 3. Visualize the top 5 countries using a horizontal bar chart showing the Composite Score.
#
# 4. Discuss whether the rankings based on the Composite Score align with the original Score - support your
# discussion with some visualization plot.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

dataset = pd.read_csv('South_Asia.csv')

# %%
# Task 1: Create the Composite Score

dataset['Composite Score'] = (0.40 * dataset['Log GDP per capita'] +
                               0.30 * dataset['Social support'] +
                               0.30 * dataset['Healthy life expectancy'])
dataset
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0        Nepal  5.158               0.965           0.990
# 1     Pakistan  4.657               1.069           0.600
# 2        India  4.054               1.166           0.653
# 3    Sri Lanka  3.898               1.361           1.179
# 4   Bangladesh  3.886               1.122           0.249
# 5  Afghanistan  1.721               0.628           0.000
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.443                         0.653       0.209
# 1                    0.321                         0.542       0.144
# 2                    0.417                         0.767       0.174
# 3                    0.586                         0.583       0.144
# 4                    0.513                         0.775       0.140
# 5                    0.242                         0.000       0.091
#
#    Perceptions of corruption  Dystopia + residual  Composite Score
# ...

# %%
# Task 2: Rank South Asian countries based on the Composite Score in descending order

ranked_south_asia = dataset.sort_values(by='Composite Score', ascending=False)

ranked_south_asia
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 3    Sri Lanka  3.898               1.361           1.179
# 0        Nepal  5.158               0.965           0.990
# 2        India  4.054               1.166           0.653
# 1     Pakistan  4.657               1.069           0.600
# 4   Bangladesh  3.886               1.122           0.249
# 5  Afghanistan  1.721               0.628           0.000
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 3                    0.586                         0.583       0.144
# 0                    0.443                         0.653       0.209
# 2                    0.417                         0.767       0.174
# 1                    0.321                         0.542       0.144
# 4                    0.513                         0.775       0.140
# 5                    0.242                         0.000       0.091
#
#    Perceptions of corruption  Dystopia + residual  Composite Score
# ...

# %%
# Task 3: Visualize the top 5 countries using a horizontal bar chart showing the Composite Score

plt.figure(figsize=(10, 6))
top_5_countries= ranked_south_asia.head(5)
sns.barplot(x='Composite Score', y='Country name', data=top_5_countries, palette='viridis')
plt.title('Top 5 Countries by Composite Score')
plt.xlabel('Composite Score')
plt.ylabel('Country')
plt.show()
# Out:
# <ipython-input-22-62d42ccb85c9>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Composite Score', y='Country name', data=top_5_countries, palette='viridis')

# %%
# Step 4: Compare rankings of Composite Score and Original Score

plt.figure(figsize=(8, 5))
sns.scatterplot(
    x='Composite Score',
    y='score',
    data=ranked_south_asia,
    hue='Country name',
    palette='tab10',
    s=100
)
plt.title('Composite Score vs Happiness Score')
plt.xlabel('Composite Score')
plt.ylabel('Original Score')
plt.legend(title='Country', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()

alignment = ranked_south_asia[['Country name', 'score', 'Composite Score']]
print("Review the rankings:\n", alignment)
print("\nThe rankings based on the Composite Score do not completely align with the Original Happiness Score.\nThis is because the Composite Score emphasizes additional factors, such as GDP, Social support and life expectancy metrics,\nwhich alter the rankings, as seen with Sri Lanka and Pakistan’s positions.")
# Out:
# Review the rankings:
#    Country name  score  Composite Score
# 3    Sri Lanka  3.898           1.0739
# 0        Nepal  5.158           0.8159
# 2        India  4.054           0.7874
# 1     Pakistan  4.657           0.7039
# 4   Bangladesh  3.886           0.6774
# 5  Afghanistan  1.721           0.3238
#
# The rankings based on the Composite Score do not completely align with the Original Happiness Score.
# This is because the Composite Score emphasizes additional factors, such as GDP, Social support and life expectancy metrics,
# which alter the rankings, as seen with Sri Lanka and Pakistan’s positions.

# %% [markdown]
# **Task - 3 - Outlier Detection:**
#
# **Tasks:**
#
# 1. Identify outlier countries in South Asia based on their Score and GDP per Capita.
#
# 2. Define outliers using the 1.5 × IQR rule.
#
# 3. Create a scatter plot with GDP per Capita on the x-axis and Score on the y-axis, highlighting outliers in a different color.
# 4. Discuss the characteristics of these outliers and their potential impact on regional averages.

# %%
import seaborn as sns

# %%
# Task 1&2: Calculate IQR for Score and GDP per Capita and define outlier using 1.5 X IQR rule

Q1_score = dataset['score'].quantile(0.25)
Q3_score = dataset['score'].quantile(0.75)
IQR_score = Q3_score - Q1_score

Q1_gdp = dataset['Log GDP per capita'].quantile(0.25)
Q3_gdp = dataset['Log GDP per capita'].quantile(0.75)
IQR_gdp = Q3_gdp - Q1_gdp

lower_bound_score = Q1_score - 1.5 * IQR_score
upper_bound_score = Q3_score + 1.5 * IQR_score

lower_bound_gdp = Q1_gdp - 1.5 * IQR_gdp
upper_bound_gdp = Q3_gdp + 1.5 * IQR_gdp

outliers_score = dataset[(dataset['score'] < lower_bound_score) | (dataset['score'] > upper_bound_score)]
outliers_gdp = dataset[(dataset['Log GDP per capita'] < lower_bound_gdp) | (dataset['Log GDP per capita'] > upper_bound_gdp)]

outliers_combined = pd.concat([outliers_score, outliers_gdp]).drop_duplicates()

print(f"Outliers based on Score:\n{outliers_score[['Country name', 'score']]}")
print(f"Outliers based on GDP per Capita:\n{outliers_gdp[['Country name', 'Log GDP per capita']]}")
# Out:
# Outliers based on Score:
#   Country name  score
# 5  Afghanistan  1.721
# Outliers based on GDP per Capita:
#   Country name  Log GDP per capita
# 5  Afghanistan               0.628

# %%
# Task 3: Scatter Plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=dataset, x='Log GDP per capita', y='score', label='Normal', color='blue')
sns.scatterplot(data=outliers_combined, x='Log GDP per capita', y='score', label='Outliers', color='red')
plt.title('Scatter Plot of GDP per Capita vs. Score')
plt.xlabel('Log GDP per Capita')
plt.ylabel('Score')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Task 4 -Discuss the characteristics of these outliers and their potential impact on regional averages.
#
# Answer:
# From the above code and output the outlier country in South Asia based on their Score and GDP per Capita is Afghanistan only.
# The characteristics of the outlier (Afghanistan) are:
# 1. Based on Score: Afghanistan score of 1.721 is significantly lower than other countries in the region, highlighting its distinct challenges.
#
# 2. Based on GDP per Capita: Afghanistan with a GDP per capita of 0.628, indicates its economic performance is significantly below the regional norms.
#
#
# The inclusion of Afghanistan in regional average can significantly lower both the Score and GDP per capita which misrepresent the other countries' performance. As an outlier, Afghanistan's data may distort the overall figures, leading to regional inequality.

# %% [markdown]
# **Task - 4 - Exploring Trends Across Metrics:**
#
# **Tasks:**
#
# 1. Choose two metrics (e.g., Freedom to Make Life Choices and Generosity) and calculate their correlation {pearson correlation} with the Score for South Asian countries.
#
# 2. Create scatter plots with trendlines for these metrics against the Score.
#
# 3. Identify and discuss the strongest and weakest relationships between these metrics and the Score for South Asian countries.

# %%
from scipy.stats import pearsonr
import seaborn as sns

# %%
# Task 1: Choose two metrics and calculate their correlation

metrics = ['Freedom to make life choices', 'Generosity']
correlations = {}

for metric in metrics:
    correlation, _ = pearsonr(dataset['score'], dataset[metric])
    correlations[metric] = correlation
    print(f"Pearson correlation between Score and {metric}: {correlation:.2f}")
# Out:
# Pearson correlation between Score and Freedom to make life choices: 0.80
# Pearson correlation between Score and Generosity: 0.87

# %%
# Task 2: Scatter Plot

# Plot for 'Freedom to Make Life Choices' vs 'Score'
plt.figure(figsize=(10, 6))
sns.regplot(x='Freedom to make life choices', y='score', data=south_asia_data, line_kws={"color": "red"})
plt.title('Freedom to Make Life Choices vs Score')
plt.xlabel('Freedom to Make Life Choices')
plt.ylabel('Score')
plt.grid(True)
plt.show()

# Plot for 'Generosity' vs 'Score'
plt.figure(figsize=(10, 6))
sns.regplot(x='Generosity', y='score', data=south_asia_data, line_kws={"color": "blue"})
plt.title('Generosity vs Score')
plt.xlabel('Generosity')
plt.ylabel('Score')
plt.grid(True)
plt.show()

# %%
# Task 3. Identify the strongest and weakest relationships.

if abs(correlations['Freedom to make life choices']) > abs(correlations['Generosity']):
    print(f"The strongest relationship is with Freedom to Make Life Choices: {correlations['Freedom to make life choices']:.2f}")
    print(f"The weakest relationship is with Generosity: {correlations['Generosity']:.2f}")
else:
    print(f"The strongest relationship is with Generosity: {correlations['Generosity']:.2f}")
    print(f"The weakest relationship is with Freedom to Make Life Choices: {correlations['Freedom to make life choices']:.2f}")

#Discussion
print("\nWhile both metrics has a moderate relation with the score for South Asian countries.\nGenerosity metric appears to have more significant impact on the score compared to Freedom to make life choices metrics.")
# Out:
# The strongest relationship is with Generosity: 0.87
# The weakest relationship is with Freedom to Make Life Choices: 0.80
#
# While both metrics has a moderate relation with the score for South Asian countries.
# Generosity metric appears to have more significant impact on the score compared to Freedom to make life choices metrics.

# %% [markdown]
# **Task - 5 - Gap Analysis:**
#
# **Tasks:**
#
# 1. Add a new column, GDP-Score Gap, which is the difference between GDP per Capita and the Score for each South Asian country.
#
# 2. Rank the South Asian countries by this gap in both ascending and descending order.
#
# 3. Highlight the top 3 countries with the largest positive and negative gaps using a bar chart.
#
# 4. Analyze the reasons behind these gaps and their implications for South Asian countries.

# %%
# Task 1. Add a new column, GDP-Score Gap, which is the difference between GDP per Capita and the Score for each South Asian country.

south_asia_data['GDP-Score Gap'] = south_asia_data['Log GDP per capita'] - south_asia_data['score']
south_asia_data
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 127                    0.586                         0.583       0.144
# 128                    0.513                         0.775       0.140
# 142                    0.242                         0.000       0.091
#
# ...

# %%
# Task 2. Rank in ascending order

ranked_ascending = south_asia_data.sort_values(by='GDP-Score Gap', ascending=True)

print("Ranked in Ascending Order:" )
ranked_ascending
# Out:
# Ranked in Ascending Order:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 128   Bangladesh  3.886               1.122           0.249
# 127    Sri Lanka  3.898               1.361           1.179
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 128                    0.513                         0.775       0.140
# 127                    0.586                         0.583       0.144
# 142                    0.242                         0.000       0.091
#
# ...

# %%
# Task 2. Rank in descending order

ranked_descending = south_asia_data.sort_values(by='GDP-Score Gap', ascending=False)

print("Ranked in Descending Order:")
ranked_descending
# Out:
# Ranked in Descending Order:
#     Country name  score  Log GDP per capita  Social support  \
# 142  Afghanistan  1.721               0.628           0.000
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
# 125        India  4.054               1.166           0.653
# 107     Pakistan  4.657               1.069           0.600
# 92         Nepal  5.158               0.965           0.990
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 142                    0.242                         0.000       0.091
# 127                    0.586                         0.583       0.144
# 128                    0.513                         0.775       0.140
# 125                    0.417                         0.767       0.174
# 107                    0.321                         0.542       0.144
# 92                     0.443                         0.653       0.209
#
# ...

# %%
# Task 3.  top 3 countries with the largest positive and negative gaps.

top_3_positive = south_asia_data.head(3)
top_3_negative = south_asia_data.tail(3)

highlighted_gaps = pd.concat([top_3_positive, top_3_negative])

# Plot Bar graph

plt.figure(figsize=(8, 6))
sns.barplot(x='GDP-Score Gap', y='Country name', data=highlighted_gaps, palette=['skyblue']*3 + ['#FFC0CB']*3)
plt.title('Top 3 Countries with the Largest Positive and Negative GDP-Score Gaps')
plt.xlabel('GDP-Score Gap')
plt.ylabel('Country')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-16-d1b3dbeb3e85>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='GDP-Score Gap', y='Country name', data=highlighted_gaps, palette=['skyblue']*3 + ['#FFC0CB']*3)

# %% [markdown]
# 4. Analyze the reasons behind these gaps and their implications for South Asian countries.
#
# Answer:
# We can say the reason behind the gaps are the disparities in social support, health, personal freedom, generosity, corruption perceptions, and dystopia factors. And to reduce these gaps, South Asian countries should enhance social services, improve grovernance, address the corruption, increase access to healthcare and personal freedom.

# %% [markdown]
# **3.3 Problem - 3 - Comparative Analysis:**
#
# **Task - 1 - Setup Task - Preparing the Middle Eastern Dataset:**
#
# **Tasks:**
#
# 1. Similar in Task - 1 of Problem 2 create a dataframe from middle eastern countries. For hint use the
# following list:
#
# middle east countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan",
# "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria", "United Arab Emirates", "Yemen"]

# %%
# List of Middle Eastern countries
middle_east_countries = ["Bahrain", "Iran", "Iraq", "Israel", "Jordan", "Kuwait",
                         "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia",
                         "Syria", "United Arab Emirates", "Yemen"]

middle_east = dataset[dataset['Country name'].isin(middle_east_countries)]

print("Filtered Dataset for Middle East Countries:")
middle_east
# Out:
# Filtered Dataset for Middle East Countries:
#              Country name  score  Log GDP per capita  Social support  \
# 4                  Israel  7.341               1.803           1.513
# 12                 Kuwait  6.951               1.845           1.364
# 21   United Arab Emirates  6.733               1.983           1.164
# 27           Saudi Arabia  6.594               1.842           1.361
# 61                Bahrain  5.959                 NaN             NaN
# 91                   Iraq  5.166               1.249           0.996
# 99                   Iran  4.923               1.435           1.136
# 124                Jordan  4.186               1.262           0.983
# 132                 Yemen  3.561               0.671           1.281
# 141               Lebanon  2.707               1.377           0.577
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 4                      0.740                         0.641       0.153
# ...

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Assignment1/middle_east.csv')

# %% [markdown]
# Complete the following task:

# %%
# 1. Descriptive Statistics

south_asia_stats = south_asia_data['score'].agg(['mean', 'std'])
middle_east_stats = middle_east['score'].agg(['mean', 'std'])

print("South Asia - Mean: {:.2f}, Std Dev: {:.2f}".format(south_asia_stats['mean'], south_asia_stats['std']))
print("Middle East - Mean: {:.2f}, Std Dev: {:.2f}".format(middle_east_stats['mean'], middle_east_stats['std']))

if south_asia_stats['mean'] > middle_east_stats['mean']:
    print("\nSouth Asia region has higher happiness scores on average.")
else:
    print("\nMiddle East region has higher happiness scores on average.")
# Out:
# South Asia - Mean: 3.90, Std Dev: 1.18
# Middle East - Mean: 5.41, Std Dev: 1.57
#
# Middle East region has higher happiness scores on average.

# %% [markdown]
# **2. Top and Bottom Performers:**
#
# • Identify the top 3 and bottom 3 countries in each region based on the score.
#
# • Plot bar charts comparing these charts.

# %%
# 2. Top and bottom performers: Identify the top 3 and bottom 3 countries in each region based on the score.

south_asia_top = south_asia_data.nlargest(3, 'score')
south_asia_bottom = south_asia_data.nsmallest(3, 'score')

middle_east_top = middle_east.nlargest(3, 'score')
middle_east_bottom = middle_east.nsmallest(3, 'score')

print("South Asia - Top 3:")
south_asia_top[['Country name', 'score']]
# Out:
# South Asia - Top 3:
#     Country name  score
# 92         Nepal  5.158
# 107     Pakistan  4.657
# 125        India  4.054

# %%
print("South Asia - Bottom 3:")
south_asia_bottom[['Country name', 'score']]
# Out:
# South Asia - Bottom 3:
#     Country name  score
# 142  Afghanistan  1.721
# 128   Bangladesh  3.886
# 127    Sri Lanka  3.898

# %%
print("Middle East - Top 3:")
middle_east_top[['Country name', 'score']]
# Out:
# Middle East - Top 3:
#             Country name  score
# 4                 Israel  7.341
# 12                Kuwait  6.951
# 21  United Arab Emirates  6.733

# %%
print("Middle East - Bottom 3:")
middle_east_bottom[['Country name', 'score']]
# Out:
# Middle East - Bottom 3:
#     Country name  score
# 141      Lebanon  2.707
# 132        Yemen  3.561
# 124       Jordan  4.186

# %%
# 2. Top and Bottom Performers: Plot bar charts comparing these charts.

performers = pd.concat([south_asia_top, south_asia_bottom, middle_east_top, middle_east_bottom])

plt.figure(figsize=(12, 6))
plt.bar(performers['Country name'], performers['score'], color=['#B2EBF2'] * 3 + ['#F4A1A1'] * 3 + ['#77DD77'] * 3 + ['#FFA07A'] * 3)
plt.title("Top and Bottom Performers in South Asia and Middle East")
plt.ylabel("Happiness Score")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **3. Metric Comparisons:**
#
# • Compare key metrics like GDP per Capita, Social Support, and Healthy Life Expectancy between the regions using grouped bar charts.
#
# • Which metrics show the largest disparity between the two regions?

# %%
# 3. Metric Comparisons:
metrics = ['Log GDP per capita', 'Social support', 'Healthy life expectancy']
south_asia_mean = south_asia_data[metrics].mean()
middle_east_mean = middle_east[metrics].mean()


labels = metrics
x = range(len(metrics))

plt.figure(figsize=(10, 6))
south_asia_bars = plt.bar(x, south_asia_mean, width=0.3, label='South Asia', color='#CFCFC4', align='center')
middle_east_bars = plt.bar([p + 0.4 for p in x], middle_east_mean, width=0.3, label='Middle East', color='#F4A460', align='center')

for i, bar in enumerate(south_asia_bars):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), round(bar.get_height(), 2),
             ha='center', va='bottom', fontweight='bold', color='black')

for i, bar in enumerate(middle_east_bars):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), round(bar.get_height(), 2),
             ha='center', va='bottom', fontweight='bold', color='black')

plt.xticks([p + 0.2 for p in x], labels, rotation=0)
plt.title("Comparison of Key Metrics Between Regions")
plt.ylabel("Mean Value")
plt.legend()
plt.show()

disparities = abs(south_asia_mean - middle_east_mean)
largest_disparity = disparities.idxmax()
print(f"Between the two regions the largest disparity is shown in: {largest_disparity}")
# Out:
# Between the two regions the largest disparity is shown in: Social support

# %% [markdown]
# **4. Happiness Disparity:**
#
# • Compute the range (max - min) and coefficient of variation (CV) for Score in both regions.
#
# • Which region has greater variability in happiness?

# %%
# 4. Happiness Disparity:

south_asia_range = south_asia_data['score'].max() - south_asia_data['score'].min()
south_asia_cv = south_asia_data['score'].std() / south_asia_data['score'].mean()

middle_east_range = middle_east['score'].max() - middle_east['score'].min()
middle_east_cv = middle_east['score'].std() / middle_east['score'].mean()

print(f"South Asia - Range: {south_asia_range:.2f}, CV: {south_asia_cv:.2f} %")
print(f"Middle East - Range: {middle_east_range:.2f}, CV: {middle_east_cv:.2f} %")

if south_asia_cv > middle_east_cv:
    print("\nSouth Asia has greater variability in happiness.")
else:
    print("\nMiddle East has greater variability in happiness.")
# Out:
# South Asia - Range: 3.44, CV: 0.30 %
# Middle East - Range: 4.63, CV: 0.29 %
#
# South Asia has greater variability in happiness.

# %% [markdown]
# **5. Correlation Analysis:**
#
# • Analyze the correlation of Score with other metrics Freedom to Make Life Choices, and Generosity within each region.
#
# • Create scatter plots to visualize and interpret the relationships.

# %%
# 5. Correlation Analysis:

from scipy.stats import pearsonr

metrics = ['Freedom to make life choices', 'Generosity']
for metric in metrics:
    sa_clean = south_asia_data[[metric, 'score']].dropna()
    corr_south_asia_data, _ = pearsonr(sa_clean[metric], sa_clean['score'])
    print(f"{metric} with Score: {corr_south_asia_data:.2f}")

    plt.figure(figsize=(8, 5))
    sns.scatterplot(x=sa_clean[metric], y=sa_clean['score'], color='red', alpha=0.7)
    sns.regplot(x=sa_clean[metric], y=sa_clean['score'], scatter_kws={'color': 'red', 'alpha': 0.7}, line_kws={'color': 'red', 'lw': 2})
    plt.title(f"South Asia: {metric} vs Score (Correlation: {corr_south_asia_data:.2f})")
    plt.xlabel(metric)
    plt.ylabel("Score")
    plt.grid(True)
    plt.show()
# Out:
# Freedom to make life choices with Score: 0.80
# Generosity with Score: 0.87

# %%
print("\nMiddle East Correlations:")
for metric in metrics:
    me_clean = middle_east[[metric, 'score']].dropna()
    corr_middle_east, _ = pearsonr(me_clean[metric], me_clean['score'])
    print(f"{metric} with Score: {corr_middle_east:.2f}")

    plt.figure(figsize=(8, 5))
    plt.scatter(me_clean[metric], me_clean['score'], color='orange', alpha=0.7)
    sns.regplot(x=me_clean[metric], y=me_clean['score'], scatter_kws={'color': 'blue', 'alpha': 0.7}, line_kws={'color': 'blue', 'lw': 2})
    plt.title(f"Middle East: {metric} vs Score (Correlation: {corr_middle_east:.2f})")
    plt.xlabel(metric)
    plt.ylabel("Score")
    plt.grid(True)
    plt.show()
# Out:
# Middle East Correlations:
# Freedom to make life choices with Score: 0.86
# Generosity with Score: 0.63

# %% [markdown]
# **6. Outlier Detection:**
#
# • Identify outlier countries in both regions based on Score and GDP per Capita.
#
# • Plot these outliers and discuss their implications.

# %%
# 6. Outlier Detection.

def identify_outliers(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = data[(data[column] < lower_bound) | (data[column] > upper_bound)]
    return outliers

metrics = ['score', 'Log GDP per capita']

print("Outliers in South Asia Region:")
for metric in metrics:
    outliers_sa = identify_outliers(south_asia_data, metric)
    print(f"\nOutliers based on {metric}:")
    print(outliers_sa[['Country name', metric]])

    # Scatter plot for South Asia Region
    plt.figure(figsize=(8, 5))
    sns.scatterplot(x=south_asia_data[metric], y=south_asia_data['score'], color='blue', label='Data Points', alpha=0.7)
    sns.scatterplot(x=outliers_sa[metric], y=outliers_sa['score'], color='red', label='Outliers', s=100, marker='X')
    plt.title(f"South Asia: {metric} vs Score with Outliers")
    plt.xlabel(metric)
    plt.ylabel("Score")
    plt.legend()
    plt.grid(True)
    plt.show()

print("\nOutliers in Middle East:")
for metric in metrics:
    outliers_me = identify_outliers(middle_east, metric)
    print(f"\nOutliers based on {metric}:")
    print(outliers_me[['Country name', metric]])

    # Scatter plot for Middle East Region
    plt.figure(figsize=(8, 5))
    sns.scatterplot(x=middle_east[metric], y=middle_east['score'], color='green', label='Data Points', alpha=0.7)
    sns.scatterplot(x=outliers_me[metric], y=outliers_me['score'], color='red', label='Outliers', s=100, marker='X')
    plt.title(f"Middle East: {metric} vs Score with Outliers")
    plt.xlabel(metric)
    plt.ylabel("Score")
    plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# Outliers in South Asia Region:
#
# Outliers based on score:
#     Country name  score
# 142  Afghanistan  1.721
# Outliers based on Log GDP per capita:
#     Country name  Log GDP per capita
# 142  Afghanistan               0.628
# Outliers in Middle East:
#
# Outliers based on score:
# Empty DataFrame
# Columns: [Country name, score]
# Index: []
# Outliers based on Log GDP per capita:
# Empty DataFrame
# Columns: [Country name, Log GDP per capita]
# Index: []

# %% [markdown]
# Discussion:
#
# Afghanistan with both low GDP and score, highlights severe economimc struggles and low life satisfactions. In contrast, Middle east has no outlier, showing a balanced growth.

# %% [markdown]
# **7. Visualization:**
#
# • Create boxplots comparing the distribution of Score between South Asia and the Middle East.
#
# • Interpret the key differences in distribution shapes, medians, and outliers.

# %%
# 7. Visualization
combined_data = pd.concat([
    south_asia_data[['Country name', 'score']].assign(Region = 'South Asia'),
    middle_east[['Country name', 'score']].assign(Region = 'Middle East')
])

plt.figure(figsize=(6, 6))
sns.boxplot(data = combined_data, x ='Region', y = 'score', palette={'South Asia': 'skyblue', 'Middle East': 'lightcoral'}, width = 0.2)

plt.title('Boxplot Comparision of Scores: South Asia vs Middle East', fontsize = 14)
plt.xlabel('Region', fontsize = 12)
plt.ylabel('score',  fontsize = 12)
plt.grid(axis = 'y', linestyle = '--', alpha = 0.7)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-35-98f3a1242e81>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data = combined_data, x ='Region', y = 'score', palette={'South Asia': 'skyblue', 'Middle East': 'lightcoral'}, width = 0.2)

# %% [markdown]
# Interpreting the key differences in distribution shapes, medians, and outliers.
# 1. Distribution Shapes: South Asia shows a more compact distribution within the IQR while Middle East has a wider distribution, indicating more variability in scores.
# 2. Medians: The median score of Middle East is around 5.5 which higher compared to South Asia whose median score is around 4.5.
# 3. Outliers: The South Asia has an outlier below the score of 2, indicating a particularly low score that stands out from the rest of the data. Meanwhile, Middle East has no outlier, suggesting a more uniform spread of scores.
